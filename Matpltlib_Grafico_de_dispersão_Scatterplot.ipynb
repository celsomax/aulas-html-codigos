# %% [markdown]
# <a href="https://colab.research.google.com/github/celsomax/aulas-html-codigos/blob/master/Matpltlib_Grafico_de_dispers%C3%A3o_Scatterplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Comparando gráfico de barras

# %%
import matplotlib.pyplot as plt
x1 = [1, 3, 5, 7, 9]
y1 = [2, 3, 7, 1, 0]
z = [200, 25, 400, 3300, 100]
titulo = "Matpltlib Grafico de dispersão - Scatterplo"
eixoX = "Eixo X"
eixoY = "Eixo Y"

plt.title(titulo)
plt.xlabel(eixoX)
plt.ylabel(eixoY)

plt.scatter(x1, y1, label = "Meus pontos", color="r", marker=".", s=z)
plt.plot(x1, y1,  color="k", linestyle="-", linewidth=15)
plt.legend()
plt.show()
